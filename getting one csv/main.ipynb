# %%
import pandas as pd
import glob
import os

# Folder containing your CSV files
folder_path = r"D:\github scrapping project\all csv files"

# Get a list of all CSV files in the folder
csv_files = glob.glob(os.path.join(folder_path, '*.csv'))

# List to hold dataframes
dataframes = []

# Loop over each CSV file
for file in csv_files:
    # Read CSV file into a DataFrame
    df = pd.read_csv(file)
    
    # Add a new column for the filename (without the path and extension)
    df['filename'] = os.path.basename(file).replace('.csv', '')
    
    # Append the DataFrame to the list
    dataframes.append(df)

# Concatenate all dataframes into a single DataFrame
merged_df = pd.concat(dataframes, ignore_index=True)

# View the result
print(merged_df)
# Out:
#      user_name          repo_name  \
# 0       mrdoob           three.js
# 1       pmndrs  react-three-fiber
# 2       libgdx             libgdx
# 3    BabylonJS         Babylon.js
# 4        ssloy       tinyrenderer
# ..         ...                ...
# 625        NaN                NaN
# 626        NaN                NaN
# 627        NaN                NaN
# 628        NaN                NaN
# 629        NaN                NaN
#
#                                         repo_url     stars filename  \
# 0             https://github.com/mrdoob/three.js  102000.0       3D
# 1    https://github.com/pmndrs/react-three-fiber   27400.0       3D
# 2               https://github.com/libgdx/libgdx   23300.0       3D
# 3        https://github.com/BabylonJS/Babylon.js   23200.0       3D
# 4          https://github.com/ssloy/tinyrenderer   20500.0       3D
# ..                                           ...       ...      ...
# 625                                          NaN       NaN   topics
# 626                                          NaN       NaN   topics
# 627                                          NaN       NaN   topics
# 628                                          NaN       NaN   topics
# 629                                          NaN       NaN   topics
#
#      Unnamed: 0                   title  \
# 0           NaN                     NaN
# 1           NaN                     NaN
# 2           NaN                     NaN
# 3           NaN                     NaN
# 4           NaN                     NaN
# ..          ...                     ...
# 625        25.0                Compiler
# 626        26.0  Continuous integration
# 627        27.0                     C++
# 628        28.0          Cryptocurrency
# 629        29.0                 Crystal
#
#                                            description  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 625  Compilers are software that translate higher-l...
# 626  Automatically build and test your code as you ...
# 627  C++ is a general purpose and object-oriented p...
# 628  A cryptocurrency is a digital currency that us...
# 629  Crystal is a self-hosted, general purpose prog...
#
#                                                   url
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 625                https://github.com/topics/compiler
# 626  https://github.com/topics/continuous-integration
# 627                     https://github.com/topics/cpp
# 628          https://github.com/topics/cryptocurrency
# 629                 https://github.com/topics/crystal
#
# [630 rows x 9 columns]

# %%
# Save the merged DataFrame to a CSV file
merged_df.to_csv('merged_data.csv', index=False)

# View the result
print("Merged CSV file created as 'merged_data.csv'")
# Out:
# Merged CSV file created as 'merged_data.csv'

# %%
pd.read_csv("merged_data.csv")
# Out:
#      user_name          repo_name  \
# 0       mrdoob           three.js
# 1       pmndrs  react-three-fiber
# 2       libgdx             libgdx
# 3    BabylonJS         Babylon.js
# 4        ssloy       tinyrenderer
# ..         ...                ...
# 625        NaN                NaN
# 626        NaN                NaN
# 627        NaN                NaN
# 628        NaN                NaN
# 629        NaN                NaN
#
#                                         repo_url     stars filename  \
# 0             https://github.com/mrdoob/three.js  102000.0       3D
# 1    https://github.com/pmndrs/react-three-fiber   27400.0       3D
# 2               https://github.com/libgdx/libgdx   23300.0       3D
# 3        https://github.com/BabylonJS/Babylon.js   23200.0       3D
# 4          https://github.com/ssloy/tinyrenderer   20500.0       3D
# ..                                           ...       ...      ...
# 625                                          NaN       NaN   topics
# 626                                          NaN       NaN   topics
# 627                                          NaN       NaN   topics
# 628                                          NaN       NaN   topics
# 629                                          NaN       NaN   topics
#
#      Unnamed: 0                   title  \
# 0           NaN                     NaN
# 1           NaN                     NaN
# 2           NaN                     NaN
# 3           NaN                     NaN
# 4           NaN                     NaN
# ..          ...                     ...
# 625        25.0                Compiler
# 626        26.0  Continuous integration
# 627        27.0                     C++
# 628        28.0          Cryptocurrency
# 629        29.0                 Crystal
#
#                                            description  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 625  Compilers are software that translate higher-l...
# 626  Automatically build and test your code as you ...
# 627  C++ is a general purpose and object-oriented p...
# 628  A cryptocurrency is a digital currency that us...
# 629  Crystal is a self-hosted, general purpose prog...
#
#                                                   url
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 625                https://github.com/topics/compiler
# 626  https://github.com/topics/continuous-integration
# 627                     https://github.com/topics/cpp
# 628          https://github.com/topics/cryptocurrency
# 629                 https://github.com/topics/crystal
#
# [630 rows x 9 columns]
